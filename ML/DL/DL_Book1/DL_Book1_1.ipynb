# %%
import numpy as np

# %%
x = np.array([1.0, 2.0, 3.0])
print(x)
# Out:
# [1. 2. 3.]

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x = np.array([1.0, 2.0, 3.0])
y = np.array([2.0, 4.0, 6.0])
print(x + y)
print(x - y)
print(x * y)
print(x / y)
# Out:
# [3. 6. 9.]
# [-1. -2. -3.]
# [ 2.  8. 18.]
# [0.5 0.5 0.5]

# %%
x = np.array([1.0, 2.0, 3.0])
x / 2.0
# Out:
# array([0.5, 1. , 1.5])

# %%
# numpy生成二维数组
A = np.array([[1,2], [3,4]])
print(A)
print(A.shape)
print(A.dtype)
# Out:
# [[1 2]
#  [3 4]]
# (2, 2)
# int32

# %%
B = np.array([[3,0],[0,6]])
print(A +B)
print(A * B)
print(A * 10)
# Out:
# [[ 4  2]
#  [ 3 10]]
# [[ 3  0]
#  [ 0 24]]
# [[10 20]
#  [30 40]]

# %%
A = np.array([[1,2],[3,4]])
B = np.array([10,20])
A * B
# Out:
# array([[10, 40],
#        [30, 80]])

# %%
X = np.array([[51,55],[14,19],[0,4]])
print(X)
print(X[0])
print(X[0][1])
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]
# [51 55]
# 55

# %%
for row in X:
    print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
X = X.flatten() #讲X转换为一维数组
print(X)
X[np.array([0,2,4])]
# print(X[0,2,4]) # X
# Out:
# [51 55 14 19  0  4]
# array([51, 14,  0])

# %%
print(X > 15)
print(X[X>15])
# Out:
# [ True  True False  True False False]
# [51 55 19]

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成数据
x = np.arange(0,6,0.1)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y1,label="sin")
plt.plot(x,y2,linestyle="--",label="cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title("sin & cos")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('D:/code/study/image/lena.jpg')
plt.imshow(img)
plt.show()
